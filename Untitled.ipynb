# %%
import pandas as pd
import numpy as pandas

# %%
df =  pd.read_csv('UCI_Credit_Card.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          5 non-null      int64
#  1   LIMIT_BAL                   5 non-null      float64
#  2   SEX                         5 non-null      int64
#  3   EDUCATION                   5 non-null      int64
#  4   MARRIAGE                    5 non-null      int64
#  5   AGE                         5 non-null      int64
#  6   PAY_0                       5 non-null      int64
#  7   PAY_2                       5 non-null      int64
#  8   PAY_3                       5 non-null      int64
#  9   PAY_4                       5 non-null      int64
#  10  PAY_5                       5 non-null      int64
#  11  PAY_6                       5 non-null      int64
#  12  BILL_AMT1                   5 non-null      float64
# ...

# %%
df.tail()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
df['SEX'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
df.isna().count()
# Out:
# ID                            5
# LIMIT_BAL                     5
# SEX                           5
# EDUCATION                     5
# MARRIAGE                      5
# AGE                           5
# PAY_0                         5
# PAY_2                         5
# PAY_3                         5
# PAY_4                         5
# PAY_5                         5
# PAY_6                         5
# BILL_AMT1                     5
# BILL_AMT2                     5
# BILL_AMT3                     5
# BILL_AMT4                     5
# BILL_AMT5                     5
# BILL_AMT6                     5
# PAY_AMT1                      5
# PAY_AMT2                      5
# PAY_AMT3                      5
# PAY_AMT4                      5
# PAY_AMT5                      5
# PAY_AMT6                      5
# default.payment.next.month    5
# dtype: int64

# %%
mean_values = df.mean()

# %%
df.fillna(mean_values, inplace = True)

# %%
df.isna().count()
# Out:
# ID                            5
# LIMIT_BAL                     5
# SEX                           5
# EDUCATION                     5
# MARRIAGE                      5
# AGE                           5
# PAY_0                         5
# PAY_2                         5
# PAY_3                         5
# PAY_4                         5
# PAY_5                         5
# PAY_6                         5
# BILL_AMT1                     5
# BILL_AMT2                     5
# BILL_AMT3                     5
# BILL_AMT4                     5
# BILL_AMT5                     5
# BILL_AMT6                     5
# PAY_AMT1                      5
# PAY_AMT2                      5
# PAY_AMT3                      5
# PAY_AMT4                      5
# PAY_AMT5                      5
# PAY_AMT6                      5
# default.payment.next.month    5
# dtype: int64

# %%
df.dtypes
# Out:
# ID                              int64
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                     float64
# BILL_AMT2                     float64
# BILL_AMT3                     float64
# BILL_AMT4                     float64
# BILL_AMT5                     float64
# BILL_AMT6                     float64
# PAY_AMT1                      float64
# PAY_AMT2                      float64
# PAY_AMT3                      float64
# PAY_AMT4                      float64
# PAY_AMT5                      float64
# PAY_AMT6                      float64
# default.payment.next.month      int64
# ...

# %%
print(df.isna().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x = df['LIMIT_BAL'])
# Out:
# <Axes: xlabel='LIMIT_BAL'>

# %%
df[['LIMIT_BAL', 'BILL_AMT1', 'PAY_AMT1']].boxplot(figsize=(10, 6))
plt.show()

# %%
# Removing outliers from the data set
import numpy as np

# %%
from scipy import stats
z_score = np.abs(stats.zscore(df[['LIMIT_BAL']]))

# %%
outlier_condition = (z_score > 3)
df_cleaned = df[~outlier_condition.any(axis=1)]

# %%
df_cleaned
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numeric_cols = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 
                'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
df
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 0   1  -1.314822    2          2         1 -0.988031      2      2     -1
# 1   2   1.543487    2          2         2 -0.817680     -1      2      0
# 2   3   0.685994    2          2         2 -0.136280      0      0      0
# 3   4  -0.457330    2          2         1  0.119245      0      0      0
# 4   5  -0.457330    1          2         1  1.822746     -1      0     -1
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -1  ...  -1.260916  -1.261498  -1.252681  -1.20203 -0.543040 -0.712775
# 1      0  ...  -0.952368  -0.933833  -0.950035  -1.20203 -0.521075 -0.442784
# 2      0  ...   0.090490   0.156141   0.190386   0.45136 -0.485761 -0.442784
# 3      0  ...   1.409080   1.484918   1.489508   0.97635 -0.449106 -0.388786
# 4      0  ...   0.713715   0.554272   0.522823   0.97635  1.998982  1.987129
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['default.payment.next.month'])

# %%
X
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 0   1  -1.314822    2          2         1 -0.988031      2      2     -1
# 1   2   1.543487    2          2         2 -0.817680     -1      2      0
# 2   3   0.685994    2          2         2 -0.136280      0      0      0
# 3   4  -0.457330    2          2         1  0.119245      0      0      0
# 4   5  -0.457330    1          2         1  1.822746     -1      0     -1
#
#    PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1  ...  -1.033106  -1.260916  -1.261498  -1.252681  -1.20203 -0.543040
# 1      0  ...  -0.928707  -0.952368  -0.933833  -0.950035  -1.20203 -0.521075
# 2      0  ...  -0.358938   0.090490   0.156141   0.190386   0.45136 -0.485761
# 3      0  ...   1.512808   1.409080   1.484918   1.489508   0.97635 -0.449106
# 4      0  ...   0.807943   0.713715   0.554272   0.522823   0.97635  1.998982
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
y = df['default.payment.next.month']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)

# %%
X_train.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 2   3   0.685994    2          2         2 -0.136280      0      0      0
# 0   1  -1.314822    2          2         1 -0.988031      2      2     -1
# 3   4  -0.457330    2          2         1  0.119245      0      0      0
#
#    PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 2      0  ...  -0.358938   0.090490   0.156141   0.190386   0.45136 -0.485761
# 0     -1  ...  -1.033106  -1.260916  -1.261498  -1.252681  -1.20203 -0.543040
# 3      0  ...   1.512808   1.409080   1.484918   1.489508   0.97635 -0.449106
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 2 -0.442784 -0.428427  0.957661  1.860190
# 0 -0.712775 -0.730136 -1.178068 -0.989191
# 3 -0.388786 -0.398256  1.105026 -0.419315
#
# [3 rows x 24 columns]

# %%
y_train
# Out:
# 2    0
# 0    1
# 3    0
# Name: default.payment.next.month, dtype: int64

# %%
X_train
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  \
# 2   3   0.685994    2          2         2 -0.136280      0      0      0
# 0   1  -1.314822    2          2         1 -0.988031      2      2     -1
# 3   4  -0.457330    2          2         1  0.119245      0      0      0
#
#    PAY_4  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 2      0  ...  -0.358938   0.090490   0.156141   0.190386   0.45136 -0.485761
# 0     -1  ...  -1.033106  -1.260916  -1.261498  -1.252681  -1.20203 -0.543040
# 3      0  ...   1.512808   1.409080   1.484918   1.489508   0.97635 -0.449106
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 2 -0.442784 -0.428427  0.957661  1.860190
# 0 -0.712775 -0.730136 -1.178068 -0.989191
# 3 -0.388786 -0.398256  1.105026 -0.419315
#
# [3 rows x 24 columns]

# %%
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.5

# %%
roc_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
print(f'ROC AUC: {roc_auc}')
# Out:
# ROC AUC: 1.0
